# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv('happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df['Region'].value_counts()
# Out:
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,9))
sns.scatterplot(data=df,x='Happiness Score',y='Economy (GDP per Capita)',s=50)
plt.grid()

# %%
plt.figure(figsize=(15,9))
sns.scatterplot(data=df,x='Happiness Score',y='Economy (GDP per Capita)',hue='Region',s=70)
plt.legend(bbox_to_anchor=(1,1))
plt.grid()

# %%
sns.scatterplot(data=df,x='Happiness Score',y='Economy (GDP per Capita)',hue='Freedom')
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Economy (GDP per Capita)'>

# %%
df.groupby(by='Region')['Economy (GDP per Capita)'].sum()
# Out:
# Region
# Australia and New Zealand           2.58376
# Central and Eastern Europe         27.33071
# Eastern Asia                        6.91068
# Latin America and Caribbean        19.28994
# Middle East and Northern Africa    21.33947
# North America                       2.72080
# Southeastern Asia                   7.10149
# Southern Asia                       3.92340
# Sub-Saharan Africa                 15.21892
# Western Europe                     27.27051
# Name: Economy (GDP per Capita), dtype: float64

# %%
plt.figure(figsize=(15,9))
df.groupby(by='Region')['Economy (GDP per Capita)'].sum().plot.pie(autopct='%.2f')
# Out:
# <Axes: ylabel='Economy (GDP per Capita)'>

# %%
df = pd.get_dummies(data=df,columns=['Region'],drop_first=True, dtype=int)

# %%
df
# Out:
#          Country  Happiness Rank  Happiness Score  Standard Error  \
# 0    Switzerland               1            7.587         0.03411
# 1        Iceland               2            7.561         0.04884
# 2        Denmark               3            7.527         0.03328
# 3         Norway               4            7.522         0.03880
# 4         Canada               5            7.427         0.03553
# ..           ...             ...              ...             ...
# 153       Rwanda             154            3.465         0.03464
# 154        Benin             155            3.340         0.03656
# 155        Syria             156            3.006         0.05015
# 156      Burundi             157            2.905         0.08658
# 157         Togo             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...

# %%
countrylist = df['Country']

# %%
countrylist
# Out:
# 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 153         Rwanda
# 154          Benin
# 155          Syria
# 156        Burundi
# 157           Togo
# Name: Country, Length: 158, dtype: object

# %%
df.drop('Country',axis=1,inplace=True)

# %%
df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
df.corr()
# Out:
#                                         Happiness Rank  Happiness Score  \
# Happiness Rank                                1.000000        -0.992105
# Happiness Score                              -0.992105         1.000000
# Standard Error                                0.158516        -0.177254
# Economy (GDP per Capita)                     -0.785267         0.780966
# Family                                       -0.733644         0.740605
# Health (Life Expectancy)                     -0.735613         0.724200
# Freedom                                      -0.556886         0.568211
# Trust (Government Corruption)                -0.372315         0.395199
# Generosity                                   -0.160142         0.180319
# Dystopia Residual                            -0.521999         0.530474
# Region_Central and Eastern Europe            -0.005132        -0.017781
# Region_Eastern Asia                          -0.065314         0.043593
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap='viridis_r')
# Out:
# <Axes: >

# %%
#From the heatmap it is clear that GDP, FAMILY AND HEALTH ARE RELATED TO HAPPINESS SCORE

# %%
sns.pairplot(df.iloc[:,:10])

# %%
fig, axes = plt.subplots(5,2, figsize=(12,20))
plotnumber = 1
for i in df.columns[:10]:
    ax = plt.subplot(5,2,plotnumber)
    sns.histplot(data=df,x=i)
    plotnumber += 1

# %%
#Now checking for outliers even though we will not drop them

# %%
fig, axes = plt.subplots(5,2,figsize=(12,30))
plotnumber = 1
for i in df.columns[:10]:
    ax = plt.subplot(5,2, plotnumber)
    sns.boxplot(data=df,y=i)
    plotnumber += 1

# %%
fig, axes = plt.subplots(5,2,figsize=(12,30))
plotnumber = 1
for i in df.columns[:10]:
    ax = plt.subplot(5,2, plotnumber)
    sns.kdeplot(data=df,x=i,fill=True)
    plotnumber += 1

# %%
df['Country'] = countrylist

# %%
df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
df.sort_values(by='Economy (GDP per Capita)',ascending=False)['Country']
# Out:
# 27                Qatar
# 16           Luxembourg
# 38               Kuwait
# 23            Singapore
# 3                Norway
#              ...
# 115             Liberia
# 143               Niger
# 130              Malawi
# 156             Burundi
# 119    Congo (Kinshasa)
# Name: Country, Length: 158, dtype: object

# %%
#These are the richest and poorest countries

# %%
df.sort_values(by='Freedom',ascending=False)[['Freedom','Country']]
# Out:
#      Freedom                 Country
# 3    0.66973                  Norway
# 0    0.66557             Switzerland
# 144  0.66246                Cambodia
# 7    0.65980                  Sweden
# 43   0.65821              Uzbekistan
# ..       ...                     ...
# 136  0.10384                  Angola
# 117  0.10081                   Sudan
# 95   0.09245  Bosnia and Herzegovina
# 101  0.07699                  Greece
# 111  0.00000                    Iraq
#
# [158 rows x 2 columns]

# %%
df.sort_values(by='Trust (Government Corruption)',ascending=False)[['Trust (Government Corruption)','Country']]
# Out:
#      Trust (Government Corruption)                 Country
# 153                        0.55191                  Rwanda
# 27                         0.52208                   Qatar
# 23                         0.49210               Singapore
# 2                          0.48357                 Denmark
# 7                          0.43844                  Sweden
# ..                             ...                     ...
# 55                         0.01031               Lithuania
# 133                        0.00872                Bulgaria
# 85                         0.00649                 Romania
# 95                         0.00227  Bosnia and Herzegovina
# 73                         0.00000               Indonesia
#
# [158 rows x 2 columns]

# %%
df.sort_values(by='Health (Life Expectancy)',ascending=False)[['Health (Life Expectancy)','Country']]
# Out:
#      Health (Life Expectancy)                   Country
# 23                    1.02525                 Singapore
# 71                    1.01328                 Hong Kong
# 45                    0.99111                     Japan
# 46                    0.96538               South Korea
# 35                    0.95562                     Spain
# ..                        ...                       ...
# 96                    0.07612                   Lesotho
# 100                   0.07566                 Swaziland
# 147                   0.06699  Central African Republic
# 127                   0.04776                  Botswana
# 122                   0.00000              Sierra Leone
#
# [158 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop(['Country','Happiness Rank','Happiness Score'],axis=1)

# %%
y = df['Happiness Score']

# %%
X
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 153         0.03464                   0.22208  0.77370
# 154         0.03656                   0.28665  0.35386
# 155         0.05015                   0.66320  0.47489
# 156         0.08658                   0.01530  0.41587
# 157         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
X_train.shape
# Out:
# (126, 17)

# %%
X_train
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 98          0.06698                   0.59066  0.73803
# 48          0.05412                   1.32376  1.21624
# 69          0.04175                   0.95847  1.22668
# 112         0.04585                   0.92049  1.18468
# 130         0.06130                   0.01604  0.41134
# ..              ...                       ...      ...
# 63          0.03135                   1.13764  1.23617
# 70          0.07197                   1.00761  0.98521
# 81          0.04524                   0.90198  1.05392
# 11          0.04454                   0.95578  1.23788
# 95          0.06913                   0.83223  0.91916
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 98                    0.54909  0.59591                        0.24249
# 48                    0.74716  0.45492                        0.30600
# 69                    0.53886  0.47610                        0.30844
# ...

# %%
y_train
# Out:
# 98     4.876
# 48     5.960
# 69     5.548
# 112    4.642
# 130    4.292
#        ...
# 63     5.716
# 70     5.477
# 81     5.192
# 11     7.226
# 95     4.949
# Name: Happiness Score, Length: 126, dtype: float64

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X_train)

# %%
X_scaled
# Out:
# array([[ 1.30732767, -0.62686028, -0.9762975 , ..., -0.18107149,
#         -0.58345997, -0.39492189],
#        [ 0.47600567,  1.14068616,  0.81148098, ..., -0.18107149,
#         -0.58345997, -0.39492189],
#        [-0.32364076,  0.25995087,  0.85051071, ..., -0.18107149,
#         -0.58345997, -0.39492189],
#        ...,
#        [-0.09803316,  0.12375022,  0.20465092, ..., -0.18107149,
#         -0.58345997, -0.39492189],
#        [-0.14328397,  0.25346513,  0.89238169, ..., -0.18107149,
#         -0.58345997, -0.39492189],
#        [ 1.44631229, -0.04442106, -0.29914664, ..., -0.18107149,
#         -0.58345997, -0.39492189]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.59773137, -0.03716378,  0.07429012,  0.31290395,  0.73058397,
#         -0.48449309,  1.39025129, -2.83624719, -0.48507125, -0.2236068 ,
#         -0.36760731, -0.40824829, -0.08944272, -0.24253563,  5.52268051,
#         -0.58345997, -0.39492189],
#        [ 0.35447493, -0.25345977,  0.16592027,  0.06211577,  0.99801474,
#         -0.46115964,  0.31225517,  1.24530183, -0.48507125, -0.2236068 ,
#          2.7202941 , -0.40824829, -0.08944272, -0.24253563, -0.18107149,
#         -0.58345997, -0.39492189],
#        [-0.53825888,  0.71506213,  0.96554374,  0.40416396, -1.43075317,
#         -1.13337017, -1.69584496,  0.661956  ,  2.06155281, -0.2236068 ,
#         -0.36760731, -0.40824829, -0.08944272, -0.24253563, -0.18107149,
#         -0.58345997, -0.39492189],
#        [ 0.24975163,  0.73152966, -0.2611263 ,  0.99703963, -2.3412992 ,
#         -1.10422326, -1.90927833, -0.60987428, -0.48507125, -0.2236068 ,
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_scaled,y_train)
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# 5.405468253968254

# %%
lm.coef_
# Out:
# array([-2.12652308e-05,  4.14857235e-01,  2.67439845e-01,  2.54406177e-01,
#         1.49775687e-01,  1.25576750e-01,  1.23742352e-01,  5.07492346e-01,
#         4.16091093e-05, -2.73813841e-05,  3.36175368e-05, -1.63598886e-05,
#        -4.39109623e-05, -1.75627065e-05,  9.94178876e-06,  4.25140086e-06,
#        -2.56040134e-05])

# %%
lmpred = lm.predict(X_test)

# %%
lmpred
# Out:
# array([4.27082899, 6.12277326, 5.83274809, 4.85758052, 6.45452494,
#        3.78079004, 5.2528849 , 3.89663772, 6.9462042 , 5.36015616,
#        4.51224128, 5.00716727, 6.26923776, 5.70876409, 5.85530466,
#        5.12876306, 5.19382742, 5.68871756, 7.4263777 , 7.5607119 ,
#        6.47675188, 5.12430639, 6.13014852, 5.88972115, 3.00646451,
#        6.48517851, 4.2186876 , 4.83927595, 3.34010806, 2.83902044,
#        3.9037678 , 4.89737669])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
sns.scatterplot(x=lmpred,y=y_test)
# Out:
# <Axes: ylabel='Happiness Score'>

# %%
print(f'The Mean Absolute Error is {mean_absolute_error(y_test,lmpred)}')
# Out:
# The Mean Absolute Error is 0.00029343908886957093

# %%
print(f'The Mean Squared Error is {mean_squared_error(y_test,lmpred)}')
# Out:
# The Mean Squared Error is 1.1470000331833047e-07

# %%
print(f'The Root Mean Squared Error (RMSE) IS {np.sqrt(mean_squared_error(y_test,lmpred))}')
# Out:
# The Root Mean Squared Error (RMSE) IS 0.0003386738893365275

# %%
r2_score(y_test,lmpred)
# Out:
# 0.9999999183455468

# %%
#We are already getting very high accuracy with Linear Regression because the size of the dataset is small and there are very few features

# %%
#Saving the model

# %%
import pickle

# %%
pickle.dump(lm, open('world_happiness_prediction_model.pkl','wb'))

# %%
#Now we will load the model and test it

# %%
model = pickle.load(open('world_happiness_prediction_model.pkl','rb'))

# %%
input_data = [0.07130,0.01804,0.54134,0.32562,0.48054,0.06977,0.30128,2.70791,0,0,0,0,0,0,0,1,0]

# %%
input = np.asarray(input_data).reshape(1,-1)

# %%
input.shape
# Out:
# (1, 17)

# %%
input
# Out:
# array([[0.0713 , 0.01804, 0.54134, 0.32562, 0.48054, 0.06977, 0.30128,
#         2.70791, 0.     , 0.     , 0.     , 0.     , 0.     , 0.     ,
#         0.     , 1.     , 0.     ]])

# %%
model.predict(input)
# Out:
# array([7.13283003])

# %%
#Our model is working very good

# %%
#We did not build SVM, DECISION TREE MODEL, GRADIENT BOOSTING MODEL BECAUSE
#There is no room for imrovement as R2 SCORE is 0.99
